# %%
import gym

env = gym.make("Taxi-v2").env

print(type(env.render()
     ))
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# <type 'NoneType'>

# %%
env.reset() # reset environment to a new, random state
env.render()

print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# Action Space Discrete(6)
# State Space Discrete(500)

# %% [markdown]
# ##  <font color='red'>R</font>,  <font color='Green'>G</font>, <font color='yellow'>Y</font>, <font color='blue'>B</font> are the possible pickup and destination locations.
# The <font color='blue'>**blue letter**</font> represents the current passenger pick-up location, and the <font color='Purple'> **purple letter**</font> is the current destination.

# %%
state = env.encode(0, 0, 6, 0) # (taxi row, taxi column, passenger index(pick-up location), destination index)
print("State:", state)

env.s = state
env.render()
# Out:
# ('State:', 24)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# # <font color='orange'>**P**</font>
# ## We can think of it like a matrix that has the number of states as rows and number of actions as columns, i.e.<font color='orange'> *a states × actions matrix*</font>.
# ## It is the reward table that is created whenever we create an environment
# ## For this simulation it has <font color='orange'>500(0-499)</font> Entries in *P* table
# ## FOr each entry we have <font color='orange'>6(0-5)</font> states from :-
#
# * 0 = **south**
# * 1 = **north**
# * 2 = **east**
# * 3 = **west**
# * 4 = **pickup**
# * 5 = **dropoff**

# %% [markdown]
# # Reward Table (<FONT COLOR='BLUE'>P</font>)

# %%
env.P[34]# to Access a particular state from Reward Table
# Out:
# {0: [(1.0, 134, -1, False)],
#  1: [(1.0, 34, -1, False)],
#  2: [(1.0, 34, -1, False)],
#  3: [(1.0, 14, -1, False)],
#  4: [(1.0, 34, -10, False)],
#  5: [(1.0, 34, -10, False)]}

# %% [markdown]
# This **dictionary** has the structure<FONT COLOR='ORANGE'> **{action: [(probability, nextstate, reward, done)]}**</FONT>.
# ## * The 0-5 corresponds to the actions (south, north, east, west, pickup, dropoff) the taxi can perform at our current state in the illustration.
# ## * In this env,<FONT COLOR='BLUE'> probability</font> is always <FONT COLOR='red'>1.0</font>.
# ## * The <FONT COLOR='BLUE'>nextstate</font> is the state we would be in if we take the action at this index of the dict
# ## * All the movement actions have a <FONT COLOR='red'>-1</font> reward and the pickup/dropoff actions have <FONT COLOR='red'>-10</font> reward in this particular state. If we are in a state where the taxi has a passenger and is on top of the right destination, we would see a reward of <FONT COLOR='red'>20</font> at the dropoff action (5)
# ## * <FONT COLOR='BLUE'>done</font> is used to tell us when we have successfully dropped off a passenger in the right location. Each successfull dropoff is the end of an episode

# %%
# to see first five states from 500
import time

for i in range(5):
    env.s=i
    print("State:", env.s)
    env.render()
    time.sleep(5)
# Out:
# ('State:', 0)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# ('State:', 1)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# ('State:', 2)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# ('State:', 3)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# ('State:', 4)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
print(env.s)# current state in which an agent is from Total 500 states
env.step(5)# We can take any of the 6(0-5) actions Defined Above at any Given state from 500 states
# Out:
# 4
# (4, -10, False, {'prob': 1.0})

# %% [markdown]
#  # <FONT COLOR='ORANGE'>Output</font>
#  **env.step( param )** function --> **state, reward, done, info**

# %% [markdown]
# # Without Reinforcement Learning with <FONT COLOR='ORANGE'>BRUTE FORCE</font>

# %% [markdown]
# 1. ## <FONT COLOR='ORANGE'>env.action_space.sample()</font> method automatically selects one random action from set of all possible actions.

# %%
env.s = 328  # set environment to illustration's state

epochs = 0
penalties, reward = 0, 0

frames = [] # for animation

done = False

while not done:
    action = env.action_space.sample()
    state, reward, done, info = env.step(action)
    print(state,reward,done,info)

    if reward == -10:
        penalties += 1
    
    # Put each rendered frame into dict for animation
    frames.append({
        'frame': env.render(mode='ansi'),
        'state': state,
        'action': action,
        'reward': reward
        }
    )

    epochs += 1
    
    
print("Timesteps taken: {}".format(epochs))
print("Penalties incurred: {}".format(penalties))
# Out:
# (428, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (248, -10, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (108, -10, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (108, -10, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -10, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (28, -10, False, {'prob': 1.0})
# (28, -10, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (28, -10, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (28, -10, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (128, -10, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -10, False, {'prob': 1.0})
# (488, -10, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (468, -10, False, {'prob': 1.0})
# (468, -10, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (268, -10, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -10, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (368, -10, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -10, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -10, False, {'prob': 1.0})
# (488, -10, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -10, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (168, -10, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (148, -10, False, {'prob': 1.0})
# (148, -10, False, {'prob': 1.0})
# (148, -10, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (128, -10, False, {'prob': 1.0})
# (128, -10, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (28, -10, False, {'prob': 1.0})
# (28, -10, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (48, -10, False, {'prob': 1.0})
# (48, -10, False, {'prob': 1.0})
# (48, -10, False, {'prob': 1.0})
# (48, -10, False, {'prob': 1.0})
# (48, -10, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (128, -10, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (108, -10, False, {'prob': 1.0})
# (108, -10, False, {'prob': 1.0})
# (108, -10, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (108, -10, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -10, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (28, -10, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (48, -10, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (168, -10, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (128, -10, False, {'prob': 1.0})
# (128, -10, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -10, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (108, -10, False, {'prob': 1.0})
# (108, -10, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (128, -10, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -10, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (288, -10, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -10, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -10, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -10, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (368, -10, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (328, -10, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (328, -10, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (28, -10, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -10, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -10, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -10, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (28, -1, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (8, -10, False, {'prob': 1.0})
# (8, -10, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (8, -1, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (108, -10, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -10, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (316, -10, False, {'prob': 1.0})
# (216, -1, False, {'prob': 1.0})
# (216, -10, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (336, -1, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (256, -1, False, {'prob': 1.0})
# (276, -1, False, {'prob': 1.0})
# (256, -1, False, {'prob': 1.0})
# (276, -1, False, {'prob': 1.0})
# (256, -1, False, {'prob': 1.0})
# (276, -1, False, {'prob': 1.0})
# (276, -10, False, {'prob': 1.0})
# (256, -1, False, {'prob': 1.0})
# (256, -10, False, {'prob': 1.0})
# (156, -1, False, {'prob': 1.0})
# (176, -1, False, {'prob': 1.0})
# (76, -1, False, {'prob': 1.0})
# (76, -10, False, {'prob': 1.0})
# (76, -10, False, {'prob': 1.0})
# (56, -1, False, {'prob': 1.0})
# (76, -1, False, {'prob': 1.0})
# (176, -1, False, {'prob': 1.0})
# (176, -10, False, {'prob': 1.0})
# (276, -1, False, {'prob': 1.0})
# (276, -10, False, {'prob': 1.0})
# (376, -1, False, {'prob': 1.0})
# (376, -1, False, {'prob': 1.0})
# (276, -1, False, {'prob': 1.0})
# (276, -10, False, {'prob': 1.0})
# (376, -1, False, {'prob': 1.0})
# (376, -10, False, {'prob': 1.0})
# (396, -1, False, {'prob': 1.0})
# (496, -1, False, {'prob': 1.0})
# (396, -1, False, {'prob': 1.0})
# (396, -10, False, {'prob': 1.0})
# (396, -1, False, {'prob': 1.0})
# (396, -1, False, {'prob': 1.0})
# (496, -1, False, {'prob': 1.0})
# (396, -1, False, {'prob': 1.0})
# (376, -1, False, {'prob': 1.0})
# (476, -1, False, {'prob': 1.0})
# (476, -10, False, {'prob': 1.0})
# (472, -1, False, {'prob': 1.0})
# (472, -1, False, {'prob': 1.0})
# (476, -1, False, {'prob': 1.0})
# (376, -1, False, {'prob': 1.0})
# (476, -1, False, {'prob': 1.0})
# (476, -1, False, {'prob': 1.0})
# (476, -1, False, {'prob': 1.0})
# (472, -1, False, {'prob': 1.0})
# (472, -10, False, {'prob': 1.0})
# (472, -1, False, {'prob': 1.0})
# (472, -1, False, {'prob': 1.0})
# (372, -1, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (492, -1, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (392, -10, False, {'prob': 1.0})
# (372, -1, False, {'prob': 1.0})
# (372, -10, False, {'prob': 1.0})
# (372, -1, False, {'prob': 1.0})
# (272, -1, False, {'prob': 1.0})
# (292, -1, False, {'prob': 1.0})
# (292, -10, False, {'prob': 1.0})
# (272, -1, False, {'prob': 1.0})
# (372, -1, False, {'prob': 1.0})
# (472, -1, False, {'prob': 1.0})
# (492, -1, False, {'prob': 1.0})
# (492, -10, False, {'prob': 1.0})
# (492, -10, False, {'prob': 1.0})
# (492, -1, False, {'prob': 1.0})
# (492, -1, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (392, -10, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (392, -10, False, {'prob': 1.0})
# (292, -1, False, {'prob': 1.0})
# (192, -1, False, {'prob': 1.0})
# (192, -10, False, {'prob': 1.0})
# (92, -1, False, {'prob': 1.0})
# (92, -1, False, {'prob': 1.0})
# (92, -1, False, {'prob': 1.0})
# (192, -1, False, {'prob': 1.0})
# (292, -1, False, {'prob': 1.0})
# (272, -1, False, {'prob': 1.0})
# (292, -1, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (392, -10, False, {'prob': 1.0})
# (292, -1, False, {'prob': 1.0})
# (292, -10, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (392, -10, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (292, -1, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (292, -1, False, {'prob': 1.0})
# (292, -10, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (392, -1, False, {'prob': 1.0})
# (292, -1, False, {'prob': 1.0})
# (292, -10, False, {'prob': 1.0})
# (272, -1, False, {'prob': 1.0})
# (292, -1, False, {'prob': 1.0})
# (292, -10, False, {'prob': 1.0})
# (292, -10, False, {'prob': 1.0})
# (292, -10, False, {'prob': 1.0})
# (272, -1, False, {'prob': 1.0})
# (272, -10, False, {'prob': 1.0})
# (172, -1, False, {'prob': 1.0})
# (72, -1, False, {'prob': 1.0})
# (92, -1, False, {'prob': 1.0})
# (92, -10, False, {'prob': 1.0})
# (192, -1, False, {'prob': 1.0})
# (192, -1, False, {'prob': 1.0})
# (192, -10, False, {'prob': 1.0})
# (172, -1, False, {'prob': 1.0})
# (172, -10, False, {'prob': 1.0})
# (192, -1, False, {'prob': 1.0})
# (192, -1, False, {'prob': 1.0})
# (192, -1, False, {'prob': 1.0})
# (172, -1, False, {'prob': 1.0})
# (152, -1, False, {'prob': 1.0})
# (152, -10, False, {'prob': 1.0})
# (52, -1, False, {'prob': 1.0})
# (52, -1, False, {'prob': 1.0})
# (52, -1, False, {'prob': 1.0})
# (52, -10, False, {'prob': 1.0})
# (72, -1, False, {'prob': 1.0})
# (172, -1, False, {'prob': 1.0})
# (172, -10, False, {'prob': 1.0})
# (272, -1, False, {'prob': 1.0})
# (272, -10, False, {'prob': 1.0})
# (372, -1, False, {'prob': 1.0})
# (472, -1, False, {'prob': 1.0})
# (472, -10, False, {'prob': 1.0})
# (476, -1, False, {'prob': 1.0})
# (476, -1, False, {'prob': 1.0})
# (376, -1, False, {'prob': 1.0})
# (376, -10, False, {'prob': 1.0})
# (376, -10, False, {'prob': 1.0})
# (276, -1, False, {'prob': 1.0})
# (376, -1, False, {'prob': 1.0})
# (376, -10, False, {'prob': 1.0})
# (376, -10, False, {'prob': 1.0})
# (396, -1, False, {'prob': 1.0})
# (396, -10, False, {'prob': 1.0})
# (396, -10, False, {'prob': 1.0})
# (376, -1, False, {'prob': 1.0})
# (276, -1, False, {'prob': 1.0})
# (296, -1, False, {'prob': 1.0})
# (276, -1, False, {'prob': 1.0})
# (276, -10, False, {'prob': 1.0})
# (276, -10, False, {'prob': 1.0})
# (296, -1, False, {'prob': 1.0})
# (276, -1, False, {'prob': 1.0})
# (256, -1, False, {'prob': 1.0})
# (276, -1, False, {'prob': 1.0})
# (176, -1, False, {'prob': 1.0})
# (156, -1, False, {'prob': 1.0})
# (256, -1, False, {'prob': 1.0})
# (256, -10, False, {'prob': 1.0})
# (256, -10, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -10, False, {'prob': 1.0})
# (336, -1, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -10, False, {'prob': 1.0})
# (356, -10, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -10, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (336, -1, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (336, -1, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (136, -1, False, {'prob': 1.0})
# (136, -10, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (216, -1, False, {'prob': 1.0})
# (216, -10, False, {'prob': 1.0})
# (216, -10, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (136, -1, False, {'prob': 1.0})
# (136, -10, False, {'prob': 1.0})
# (116, -1, False, {'prob': 1.0})
# (136, -1, False, {'prob': 1.0})
# (156, -1, False, {'prob': 1.0})
# (176, -1, False, {'prob': 1.0})
# (176, -10, False, {'prob': 1.0})
# (196, -1, False, {'prob': 1.0})
# (296, -1, False, {'prob': 1.0})
# (296, -1, False, {'prob': 1.0})
# (296, -10, False, {'prob': 1.0})
# (296, -1, False, {'prob': 1.0})
# (296, -10, False, {'prob': 1.0})
# (196, -1, False, {'prob': 1.0})
# (96, -1, False, {'prob': 1.0})
# (96, -10, False, {'prob': 1.0})
# (76, -1, False, {'prob': 1.0})
# (176, -1, False, {'prob': 1.0})
# (176, -10, False, {'prob': 1.0})
# (196, -1, False, {'prob': 1.0})
# (196, -10, False, {'prob': 1.0})
# (196, -10, False, {'prob': 1.0})
# (96, -1, False, {'prob': 1.0})
# (96, -1, False, {'prob': 1.0})
# (96, -1, False, {'prob': 1.0})
# (96, -1, False, {'prob': 1.0})
# (76, -1, False, {'prob': 1.0})
# (96, -1, False, {'prob': 1.0})
# (76, -1, False, {'prob': 1.0})
# (76, -10, False, {'prob': 1.0})
# (76, -10, False, {'prob': 1.0})
# (76, -1, False, {'prob': 1.0})
# (56, -1, False, {'prob': 1.0})
# (156, -1, False, {'prob': 1.0})
# (136, -1, False, {'prob': 1.0})
# (136, -10, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (256, -1, False, {'prob': 1.0})
# (256, -10, False, {'prob': 1.0})
# (256, -10, False, {'prob': 1.0})
# (256, -10, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -10, False, {'prob': 1.0})
# (336, -1, False, {'prob': 1.0})
# (436, -1, False, {'prob': 1.0})
# (336, -1, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (236, -10, False, {'prob': 1.0})
# (216, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -10, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -10, False, {'prob': 1.0})
# (308, -10, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (416, -10, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (316, -10, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -10, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -10, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -10, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -10, False, {'prob': 1.0})
# (308, -10, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -10, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (268, -10, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (168, -10, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (268, -10, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (288, -10, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -10, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (168, -10, False, {'prob': 1.0})
# (168, -10, False, {'prob': 1.0})
# (168, -10, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (328, -10, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (328, -10, False, {'prob': 1.0})
# (328, -10, False, {'prob': 1.0})
# (328, -10, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (148, -10, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (248, -10, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (128, -10, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (128, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (328, -10, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (328, -10, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (268, -10, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (168, -10, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (288, -10, False, {'prob': 1.0})
# (288, -10, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (288, -10, False, {'prob': 1.0})
# (288, -10, False, {'prob': 1.0})
# (288, -10, False, {'prob': 1.0})
# (288, -10, False, {'prob': 1.0})
# (288, -10, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (188, -10, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (168, -10, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (148, -10, False, {'prob': 1.0})
# (148, -10, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (248, -10, False, {'prob': 1.0})
# (248, -10, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (448, -10, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (468, -10, False, {'prob': 1.0})
# (468, -10, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -10, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (368, -10, False, {'prob': 1.0})
# (368, -10, False, {'prob': 1.0})
# (368, -10, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -10, False, {'prob': 1.0})
# (488, -10, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (388, -10, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (488, -1, False, {'prob': 1.0})
# (388, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (468, -10, False, {'prob': 1.0})
# (468, -1, False, {'prob': 1.0})
# (468, -10, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (368, -1, False, {'prob': 1.0})
# (368, -10, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (148, -10, False, {'prob': 1.0})
# (148, -10, False, {'prob': 1.0})
# (148, -10, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (48, -1, False, {'prob': 1.0})
# (48, -10, False, {'prob': 1.0})
# (68, -1, False, {'prob': 1.0})
# (68, -10, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (88, -10, False, {'prob': 1.0})
# (88, -1, False, {'prob': 1.0})
# (188, -1, False, {'prob': 1.0})
# (288, -1, False, {'prob': 1.0})
# (268, -1, False, {'prob': 1.0})
# (268, -10, False, {'prob': 1.0})
# (268, -10, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (248, -10, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (168, -1, False, {'prob': 1.0})
# (168, -10, False, {'prob': 1.0})
# (168, -10, False, {'prob': 1.0})
# (168, -10, False, {'prob': 1.0})
# (148, -1, False, {'prob': 1.0})
# (148, -10, False, {'prob': 1.0})
# (148, -10, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (428, -10, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (448, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (428, -1, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (328, -10, False, {'prob': 1.0})
# (328, -10, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (248, -10, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (348, -1, False, {'prob': 1.0})
# (348, -10, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (328, -10, False, {'prob': 1.0})
# (328, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (108, -1, False, {'prob': 1.0})
# (108, -10, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (248, -1, False, {'prob': 1.0})
# (228, -1, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (228, -10, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -10, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (208, -1, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (208, -10, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -10, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (308, -10, False, {'prob': 1.0})
# (308, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (408, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (416, -10, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (316, -10, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (316, -10, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (416, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (216, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (316, -10, False, {'prob': 1.0})
# (316, -1, False, {'prob': 1.0})
# (216, -1, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (256, -1, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (336, -1, False, {'prob': 1.0})
# (336, -10, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -10, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (456, -1, False, {'prob': 1.0})
# (456, -1, False, {'prob': 1.0})
# (456, -1, False, {'prob': 1.0})
# (456, -10, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (336, -1, False, {'prob': 1.0})
# (336, -10, False, {'prob': 1.0})
# (336, -10, False, {'prob': 1.0})
# (436, -1, False, {'prob': 1.0})
# (456, -1, False, {'prob': 1.0})
# (436, -1, False, {'prob': 1.0})
# (436, -1, False, {'prob': 1.0})
# (436, -10, False, {'prob': 1.0})
# (456, -1, False, {'prob': 1.0})
# (456, -1, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (336, -1, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -10, False, {'prob': 1.0})
# (356, -10, False, {'prob': 1.0})
# (356, -10, False, {'prob': 1.0})
# (336, -1, False, {'prob': 1.0})
# (336, -10, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -10, False, {'prob': 1.0})
# (456, -1, False, {'prob': 1.0})
# (456, -10, False, {'prob': 1.0})
# (456, -1, False, {'prob': 1.0})
# (456, -10, False, {'prob': 1.0})
# (356, -1, False, {'prob': 1.0})
# (356, -10, False, {'prob': 1.0})
# (456, -1, False, {'prob': 1.0})
# (456, -1, False, {'prob': 1.0})
# (436, -1, False, {'prob': 1.0})
# (336, -1, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (236, -10, False, {'prob': 1.0})
# (216, -1, False, {'prob': 1.0})
# (216, -1, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (136, -1, False, {'prob': 1.0})
# (236, -1, False, {'prob': 1.0})
# (136, -1, False, {'prob': 1.0})
# (36, -1, False, {'prob': 1.0})
# (16, -1, False, {'prob': 1.0})
# (116, -1, False, {'prob': 1.0})
# (216, -1, False, {'prob': 1.0})
# (116, -1, False, {'prob': 1.0})
# (116, -10, False, {'prob': 1.0})
# (16, -1, False, {'prob': 1.0})
# (0, 20, True, {'prob': 1.0})
# Timesteps taken: 1116
# Penalties incurred: 353

# %%
print((frames['frame'].getvalue()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-32d8c11317e2> in <module>()
# ----> 1 print((frames['frame'].getvalue()))
#
# TypeError: list indices must be integers, not str

# %%
from IPython.display import clear_output
from time import sleep

def print_frames(frames):
    for i, frame in enumerate(frames):
        clear_output(wait=True)
        print(frame['frame'].getvalue())
        print("Timestep: { }".format(i+1))
        print("State: {}".format(frame['state']))
        print("Action: {}".format(frame['action']))
        print("Reward: {}".format(frame['reward']))
        sleep(.1)
        
print_frames(frames)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-2558099160dc> in <module>()
#      12         sleep(.1)
#      13
# ---> 14 print_frames(frames)
#
# <ipython-input-153-2558099160dc> in print_frames(frames)
#       5     for i, frame in enumerate(frames):
#       6         clear_output(wait=True)
# ----> 7         print(frames['frame'].getvalue())
#       8         print("Timestep: { }".format(i+1))
#       9         print("State: {}".format(frame['state']))
#
# TypeError: list indices must be integers, not str
