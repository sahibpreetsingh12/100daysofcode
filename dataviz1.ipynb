# %% [markdown]
# <a href="https://colab.research.google.com/github/sahibpreetsingh12/100daysofcode/blob/master/dataviz1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#!pip install xlrd
#from google.colab import files
#uploaded = files.upload()
#!pip install xlrd
df=pd.read_csv("fbi.csv")#file on my pc

df.columns
df.rename(columns={'          Year':'Year'},inplace=True)
df.set_index("Year",inplace=True)
df.head()
# Out:
#       Population1  Violentcrime2  Violent_crime_rate_  \
# Year
# 1997    267783607        1636096                611.0
# 1998    270248003        1533887                567.6
# 1999    272690813        1426044                523.0
# 2000    281421906        1425486                506.5
# 2001    285317559        1439480                504.5
#
#       Murder_nonnegligent_manslaughter  \
# Year
# 1997                             18208
# 1998                             16974
# 1999                             15522
# 2000                             15586
# 2001                             16037
#
#       Murder__nonnegligent_manslaughter_rate_  Robbery  Robbery_rate_  \
# Year
# 1997                                      6.8   498534          186.2
# 1998                                      6.3   447186          165.5
# 1999                                      5.7   409371          150.1
# 2000                                      5.5   408016          145.0
# 2001                                      5.6   423557          148.5
#
#       Aggravated_assault  Aggravated_assault_rate_  Property_crime  \
# Year
# 1997             1023201                     382.1        11558475
# 1998              976583                     361.4        10951827
# 1999              911740                     334.3        10208334
# 2000              911706                     324.0        10182584
# 2001              909023                     318.6        10437189
#
#       Property_crime_rate_  Burglary  Burglary_rate_  Larceny-theft  \
# Year
# 1997                4316.3   2460526           918.8        7743760
# 1998                4052.5   2332735           863.2        7376311
# 1999                3743.6   2100739           770.4        6955520
# 2000                3618.3   2050992           728.8        6971590
# 2001                3658.1   2116531           741.8        7092267
#
#       Larceny-theft_rate_  Motor_vehicle_theft  Motor_vehicle_theft_rate_
# Year
# 1997               2891.8              1354189                      505.7
# 1998               2729.5              1242781                      459.9
# 1999               2550.7              1152075                      422.5
# 2000               2477.3              1160002                      412.2
# 2001               2485.7              1228391                      430.5

# %%
df.reset_index(inplace=True)# to create Year as column which was earlier as an index
df# complete dataset
# Out:
#     Year  Population1  Violentcrime2  Violent_crime_rate_  \
# 0   1997    267783607        1636096                611.0
# 1   1998    270248003        1533887                567.6
# 2   1999    272690813        1426044                523.0
# 3   2000    281421906        1425486                506.5
# 4   2001    285317559        1439480                504.5
# 5   2002    287973924        1423677                494.4
# 6   2003    290788976        1383676                475.8
# 7   2004    293656842        1360088                463.2
# 8   2005    296507061        1390745                469.0
# 9   2006    299398484        1435123                479.3
# 10  2007    301621157        1422970                471.8
# 11  2008    304059724        1394461                458.6
# 12  2009    307006550        1325896                431.9
# 13  2010    309330219        1251248                404.5
# 14  2011    311587816        1206005                387.1
# 15  2012    313873685        1217057                387.8
# 16  2013    316497531        1168298                369.1
# 17  2014    318907401        1153022                361.6
#
#     Murder_nonnegligent_manslaughter  Murder__nonnegligent_manslaughter_rate_  \
# 0                              18208                                      6.8
# 1                              16974                                      6.3
# 2                              15522                                      5.7
# 3                              15586                                      5.5
# 4                              16037                                      5.6
# 5                              16229                                      5.6
# 6                              16528                                      5.7
# 7                              16148                                      5.5
# 8                              16740                                      5.6
# 9                              17309                                      5.8
# 10                             17128                                      5.7
# 11                             16465                                      5.4
# 12                             15399                                      5.0
# 13                             14722                                      4.8
# 14                             14661                                      4.7
# 15                             14856                                      4.7
# 16                             14319                                      4.5
# 17                             14164                                      4.4
#
#     Robbery  Robbery_rate_  Aggravated_assault  Aggravated_assault_rate_  \
# 0    498534          186.2             1023201                     382.1
# 1    447186          165.5              976583                     361.4
# 2    409371          150.1              911740                     334.3
# 3    408016          145.0              911706                     324.0
# 4    423557          148.5              909023                     318.6
# 5    420806          146.1              891407                     309.5
# 6    414235          142.5              859030                     295.4
# 7    401470          136.7              847381                     288.6
# 8    417438          140.8              862220                     290.8
# 9    449246          150.0              874096                     292.0
# 10   447324          148.3              866358                     287.2
# 11   443563          145.9              843683                     277.5
# 12   408742          133.1              812514                     264.7
# 13   369089          119.3              781844                     252.8
# 14   354746          113.9              752423                     241.5
# 15   355051          113.1              762009                     242.8
# 16   345093          109.0              726777                     229.6
# 17   322905          101.3              731089                     229.2
#
#     Property_crime  Property_crime_rate_  Burglary  Burglary_rate_  \
# 0         11558475                4316.3   2460526           918.8
# 1         10951827                4052.5   2332735           863.2
# 2         10208334                3743.6   2100739           770.4
# 3         10182584                3618.3   2050992           728.8
# 4         10437189                3658.1   2116531           741.8
# 5         10455277                3630.6   2151252           747.0
# 6         10442862                3591.2   2154834           741.0
# 7         10319386                3514.1   2144446           730.3
# 8         10174754                3431.5   2155448           726.9
# 9         10019601                3346.6   2194993           733.1
# 10         9882212                3276.4   2190198           726.1
# 11         9774152                3214.6   2228887           733.0
# 12         9337060                3041.3   2203313           717.7
# 13         9112625                2945.9   2168459           701.0
# 14         9052743                2905.4   2185140           701.3
# 15         9001992                2868.0   2109932           672.2
# 16         8651892                2733.6   1932139           610.5
# 17         8209010                2574.1   1713153           537.2
#
#     Larceny-theft  Larceny-theft_rate_  Motor_vehicle_theft  \
# 0         7743760               2891.8              1354189
# 1         7376311               2729.5              1242781
# 2         6955520               2550.7              1152075
# 3         6971590               2477.3              1160002
# 4         7092267               2485.7              1228391
# 5         7057379               2450.7              1246646
# 6         7026802               2416.5              1261226
# 7         6937089               2362.3              1237851
# 8         6783447               2287.8              1235859
# 9         6626363               2213.2              1198245
# 10        6591542               2185.4              1100472
# 11        6586206               2166.1               959059
# 12        6338095               2064.5               795652
# 13        6204601               2005.8               739565
# 14        6151095               1974.1               716508
# 15        6168874               1965.4               723186
# 16        6019465               1901.9               700288
# 17        5809054               1821.5               686803
#
#     Motor_vehicle_theft_rate_
# 0                       505.7
# 1                       459.9
# 2                       422.5
# 3                       412.2
# 4                       430.5
# 5                       432.9
# 6                       433.7
# 7                       421.5
# 8                       416.8
# 9                       400.2
# 10                      364.9
# 11                      315.4
# 12                      259.2
# 13                      239.1
# 14                      230.0
# 15                      230.4
# 16                      221.3
# 17                      215.4

# %%
df['Population1']=df['Population1']/10000000# normalsing population effect
df.head()
# Out:
#    Year  Population1  Violentcrime2  Violent_crime_rate_  \
# 0  1997    26.778361        1636096                611.0
# 1  1998    27.024800        1533887                567.6
# 2  1999    27.269081        1426044                523.0
# 3  2000    28.142191        1425486                506.5
# 4  2001    28.531756        1439480                504.5
#
#    Murder_nonnegligent_manslaughter  Murder__nonnegligent_manslaughter_rate_  \
# 0                             18208                                      6.8
# 1                             16974                                      6.3
# 2                             15522                                      5.7
# 3                             15586                                      5.5
# 4                             16037                                      5.6
#
#    Robbery  Robbery_rate_  Aggravated_assault  Aggravated_assault_rate_  \
# 0   498534          186.2             1023201                     382.1
# 1   447186          165.5              976583                     361.4
# 2   409371          150.1              911740                     334.3
# 3   408016          145.0              911706                     324.0
# 4   423557          148.5              909023                     318.6
#
#    Property_crime  Property_crime_rate_  Burglary  Burglary_rate_  \
# 0        11558475                4316.3   2460526           918.8
# 1        10951827                4052.5   2332735           863.2
# 2        10208334                3743.6   2100739           770.4
# 3        10182584                3618.3   2050992           728.8
# 4        10437189                3658.1   2116531           741.8
#
#    Larceny-theft  Larceny-theft_rate_  Motor_vehicle_theft  \
# 0        7743760               2891.8              1354189
# 1        7376311               2729.5              1242781
# 2        6955520               2550.7              1152075
# 3        6971590               2477.3              1160002
# 4        7092267               2485.7              1228391
#
#    Motor_vehicle_theft_rate_
# 0                      505.7
# 1                      459.9
# 2                      422.5
# 3                      412.2
# 4                      430.5

# %%
df.plot.line(x='Year',y='Population1')
df.plot.line(x='Year',y='Violent_crime_rate_')
#this shows that violent crime rate has decreased from 1997 to 2014
#although there is linear increase in population of USA so USA has has hadelled there Population to employement ratio very well 
#with a little increase in 2005-2008 which be due to  global recession

# %%
df.plot.line(x='Year',y='Murder__nonnegligent_manslaughter_rate_')##this shows that Murder and nonnegligent manslaughter rate has decreased from 1997 to 2014

# %%
df.plot.line(x='Year',y='Robbery_rate_')
#similarly there is decrease in every ciminal activity with increase in population from 1997-2104
